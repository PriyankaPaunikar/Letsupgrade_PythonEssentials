# %% [markdown]
# # ASSIGNMENT 1

# %%
name = "Priyanka Paunikar"

# %%
name.index("i")
# Out:
# 2

# %%
name.split()
# Out:
# ['Priyanka', 'Paunikar']

# %%
name.count("Priyanka")
# Out:
# 1

# %%
name.capitalize()
# Out:
# 'Priyanka paunikar'

# %%
name.casefold()
# Out:
# 'priyanka paunikar'

# %%
name.isalnum()
# Out:
# False

# %%
name.isalpha()
# Out:
# False

# %%
name.upper()
# Out:
# 'PRIYANKA PAUNIKAR'

# %%
name.find("yan")
# Out:
# 3

# %%
address = "Pune"

# %%
name +" "+ address
# Out:
# 'Priyanka Paunikar Pune'

# %% [markdown]
# # ASSIGNMENT 2

# %%
lst = [1, 3, 3, 5, 6.03, "cat", "dog"]

# %%
lst.append("horse")

# %%
lst
# Out:
# [1, 3, 3, 5, 6.03, 'cat', 'dog', 'horse']

# %%
lst.count(3)
# Out:
# 2

# %%
lst.index("cat")
# Out:
# 5

# %%
lst.pop(1)
# Out:
# 3

# %%
lst
# Out:
# [1, 3, 5, 6.03, 'cat', 'dog', 'horse']

# %%
lst.reverse()

# %%
lst
# Out:
# ['horse', 'dog', 'cat', 6.03, 5, 3, 1]

# %%
lst.insert(1,"bee")

# %%
lst
# Out:
# ['horse', 'bee', 'dog', 'cat', 6.03, 5, 3, 1]

# %% [markdown]
# # ASSIGNMENT 3

# %%
dict1 = {"fruit1" : "apple", "fruit2" : "banana", "fruit3" : "kiwi", "fruit4" : "orange"}

# %%
dict1
# Out:
# {'fruit1': 'apple', 'fruit2': 'banana', 'fruit3': 'kiwi', 'fruit4': 'orange'}

# %%
dict1.get("fruit3")
# Out:
# 'kiwi'

# %%
dict1.items()
# Out:
# dict_items([('fruit1', 'apple'), ('fruit2', 'banana'), ('fruit3', 'kiwi'), ('fruit4', 'orange')])

# %%
dict1.update({"fruit3" : "mango"})

# %%
dict1
# Out:
# {'fruit1': 'apple', 'fruit2': 'banana', 'fruit3': 'mango', 'fruit4': 'orange'}

# %%
dict1.values()
# Out:
# dict_values(['apple', 'banana', 'mango', 'orange'])

# %%
dict1.copy()
# Out:
# {'fruit1': 'apple', 'fruit2': 'banana', 'fruit3': 'mango', 'fruit4': 'orange'}

# %%
dict1.keys()
# Out:
# dict_keys(['fruit1', 'fruit2', 'fruit3', 'fruit4'])

# %%
dict1.pop("fruit4")
# Out:
# 'orange'

# %%
dict1
# Out:
# {'fruit1': 'apple', 'fruit2': 'banana', 'fruit3': 'mango'}
